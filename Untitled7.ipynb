# %%
from src.haive.agents.react_agent2.agent import create_react_agent
from src.haive.agents.react_agent2.models import ReactState
from langchain_core.messages import HumanMessage
# Out:
# /home/will/Projects/haive/backend/haive/.venv/lib/python3.12/site-packages/pydantic/_internal/_config.py:345: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'populate_by_name'
# * 'orm_mode' has been renamed to 'from_attributes'
#   warnings.warn(message, UserWarning)
# /home/will/Projects/haive/backend/haive/.venv/lib/python3.12/site-packages/pydantic/_internal/_fields.py:192: UserWarning: Field name "schema" in "AgentConfig" shadows an attribute in parent "BaseModel"
#   warnings.warn(
# /home/will/Projects/haive/backend/haive/.venv/lib/python3.12/site-packages/pydantic/_internal/_fields.py:192: UserWarning: Field name "schema" in "ReactAgentConfig" shadows an attribute in parent "AgentConfig"
#   warnings.warn(

# %%
from src.haive.core.tools.search_tools import tavily_search_tool
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
a = create_react_agent(tools=[tavily_search_tool])
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a = create_react_agent(tools=[tavily_search_tool])
#
# File ~/Projects/haive/backend/haive/src/haive/agents/react_agent2/agent.py:136, in create_react_agent(tools, system_prompt, model, temperature, max_iterations, max_retry_attempts, name, visualize)
#     119 """
#     120 Create a React agent with the specified configuration.
#     121
#    (...)
#     133     A ReactAgent instance
#     134 """
#     135 # Create config
# --> 136 config = ReactAgentConfig.from_scratch(
#     137     tools=tools,
#     138     system_prompt=system_prompt,
#     139     model=model,
#     140     temperature=temperature,
#     141     max_iterations=max_iterations,
#     142     max_retry_attempts=max_retry_attempts,
#     143     name=name or "react_agent",
#     144     visualize=visualize
#     145 )
#     147 # Build and return agent
#     148 return config.build_agent()
#
# File ~/Projects/haive/backend/haive/src/haive/agents/react_agent2/config.py:183, in ReactAgentConfig.from_scratch(cls, tools, system_prompt, model, temperature, max_iterations, max_retry_attempts, name, **kwargs)
#     173 llm_config = AzureLLMConfig(
#     174     model=model,
#     175     parameters={"temperature": temperature}
#     176 )
#     178 # Create AugLLM for thinking
#     179 think_llm = AugLLMConfig(
#     180     name="think_llm",
#     181     llm_config=llm_config,
#     182     prompt_template=think_prompt,
# --> 183     structured_output_model=Thought()
#     184 )
#     185 #print(think_llm)
#     186 # Add to config
#     187 config.think_llm = think_llm
#
# File ~/Projects/haive/backend/haive/.venv/lib/python3.12/site-packages/pydantic/main.py:214, in BaseModel.__init__(self, **data)
#     212 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     213 __tracebackhide__ = True
# --> 214 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     215 if self is not validated_self:
#     216     warnings.warn(
#     217         'A custom validator is returning a value other than `self`.\n'
#     218         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     219         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     220         stacklevel=2,
#     221     )
#
# ValidationError: 2 validation errors for Thought
# thought
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# action
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing

# %%
print(a.app)

# %%
#result = agent.run("Tell me about machine learning.")
from IPython.display import Image, display

#try:
display(Image(a.app.get_graph().draw_mermaid_png()))

# %%
#a.app.invoke({'messages':[HumanMessage(content='hi')]})

# %%
for item in a.app.invoke(input=ReactState(messages=[HumanMessage(content="What is the birthday of the most recent wimbledon winner")]),debug=True,config={'configurable':{'thread_id':'8'}}):
    print(item)
