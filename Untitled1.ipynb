# %%
from src.haive.agents.react_agent.agent import ReactAgentConfig,ReactAgent
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# /Users/will/Projects/codomatic/hive_v6/hive_v6/.venv/lib/python3.11/site-packages/pydantic/_internal/_config.py:345: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'populate_by_name'
# * 'orm_mode' has been renamed to 'from_attributes'
#   warnings.warn(message, UserWarning)
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.haive.agents.react_agent.agent import ReactAgentConfig,ReactAgent
#
# File ~/Projects/haive_master/haive/src/haive/agents/react_agent/agent.py:21
#      19 from typing import Dict,Any
#      20 from langchain_core.tools import BaseTool,StructuredTool
# ---> 21 from src.haive.agents.react_agent.aug_llms import default_react_llm_runnable_config
# ...

# %%
class ListState(BaseModel
